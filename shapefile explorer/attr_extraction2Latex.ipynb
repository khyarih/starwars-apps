# %% [markdown]
# ### Automatically extraction of attributes, types and write the results to latex

# %%
import os
import concurrent.futures
from osgeo import ogr

# %%
# Set global variables
root_dir = '../data_sets/' # Root directory
dirs = ['dataset I/','dataset II/','dataset III/','dataset IV/'] # List of directories to be searched
# dirs = ['dataset IV/'] # List of directories to be searched
out_tex_file = 'report/attributes.tex'

field_names_in_file = {} # List to hold the field names
data = {} # Dictionary to hold the data

# %%
# Gather all shapefile paths
# shapefiles = []
# for dir in dirs:
#     # Traverse directory
#     for dir_name, subdir_list, file_list in os.walk(root_dir + dir):
#         for fname in file_list:
#             # Check if the file is a shapefile
#             if fname.endswith('.shp'):
#                 shapefiles.append(os.path.join(dir_name, fname))

# %%
comp_file_dict = {
    'Pipe':['dataset I/EST_OUEST/canalisations_EO',
            'dataset I/RESEAU_MAERA/canalisations',
            'dataset I/RESEAU/canalisations',
            'dataset II/A_TRONCON',
            'dataset III/M3M/A_TRONCON',
            'dataset IV/ass_rassa',
            'dataset IV/ReseauMarcheTopo',
            ],
    'Service Line':['dataset I/EST_OUEST/canalisations_de_branchement_EO', 
                    'dataset I/RESEAU/canalisations_de_branchement',
                    'dataset II/A_BRANCHEMENT_LINE', 
                    'dataset III/M3M/A_BRANCHEMENT',
                    'dataset IV/ass_brat'
                    ],
    'Connection Point':['dataset I/EST_OUEST/branchements_EO', 
                        'dataset I/RESEAU/branchements',
                        'dataset II/A_BRANCHEMENT_POINT',
                        'dataset IV/ass_bran'
                        ],
    'Manhole':['dataset I/EST_OUEST/regards_EO', 
               'dataset I/RESEAU_MAERA/regards_contrat_maera',
               'dataset I/RESEAU/regards',
               'dataset II/A_REGARD', 
               'dataset III/M3M/A_REGARD', 
               'dataset IV/REG'
               ],
    'Fitting':['dataset I/EST_OUEST/raccords_EO', 
               'dataset I/RESEAU_MAERA/raccords_contrat_maera',
               'dataset I/RESEAU/raccords',
               'dataset IV/RAC'
               ],
    'Pump Stattion':['dataset I/EST_OUEST/pompages_EO', 
                     'dataset I/RESEAU_MAERA/pompages_contrat_maera', 
                     'dataset I/RESEAU/pompages', 
                     'dataset IV/PMP'
                     ],
    'Sewage Treatment':['dataset I/EST_OUEST/station_de_traitement_EO', 
                        'dataset I/RESEAU_MAERA/station_de_traitement_contrat_maera', 
                        'dataset I/RESEAU/station_de_traitement',
                        'dataset IV/TRA'
                        ],
    'Structure':['dataset I/EST_OUEST/ouvrages_EO', 
                 'dataset I/RESEAU_MAERA/ouvrages_contrat_maera', 
                 'dataset I/RESEAU/ouvrages', 
                 'dataset II/A_OUVRAGE', 
                 'dataset III/M3M/A_OUVRAGE', 
                 'dataset IV/OUV'
                 ],
    'Accessories': ['dataset II/A_ACCESSOIRE', 
                   'dataset III/M3M/A_ACCESSOIRE'
                   ],
    'Others':['dataset IV/CommuneExploitant',
              'dataset IV/recolementEU'
              ]
    } # Dictionary to hold the file names

# %%
# Gather all shapefile paths
shapefiles = []
for comp, files in comp_file_dict.items():
    for f in files:
        shapefiles.append(root_dir + f +'.shp')

# %%
for shapefile in shapefiles:
    # Open the shapefile
    ds = ogr.Open(shapefile)
    
    if ds is None:
        print('Could not open file: ' + shapefile)
        continue
    
    lyr = ds.GetLayer()
    
    # Get the field names
    field_names_in_file[shapefile] = [field.name for field in lyr.schema]
        
    # Close the shapefile
    ds = None

# %%
# for sh in shapefiles:
#     print(sh)

# %%
# Load the shapefile data in root directory and subdirectories

# The function to be run in parallel
def process_shapefile(file_path):
    print('Processing %s' % file_path)
    # Get the field names
    # Open the shapefile
    ds = ogr.Open(file_path)
    
    if ds is None:
        print('Could not open file: ' + file_path)
        return None, None
    
    lyr = ds.GetLayer()
    fld_names = [field.name for field in lyr.schema]

    flds_data = {}
    # Get the data
    lyr.ResetReading()
    for feat in lyr: # For each feature
        for fld in fld_names:
            if fld not in flds_data:
                flds_data[fld] = []
            flds_data[fld].append(feat.GetField(fld))

    return fld_names, flds_data

# Process all shapefiles in parallel
with concurrent.futures.ThreadPoolExecutor() as executor:
    future_to_file = {executor.submit(process_shapefile, shp): shp for shp in shapefiles}
    for future in concurrent.futures.as_completed(future_to_file):
        file = future_to_file[future]
        # fname = os.path.basename(file)
        fname = file.removeprefix(root_dir)
        try:
            fld_names, flds_data = future.result()
        except Exception as exc:
            print('%r generated an exception: %s' % (file, exc))
        else:
            field_names_in_file[fname] = fld_names
            data[fname] = flds_data
# Out:
# Processing ../data_sets/dataset I/EST_OUEST/canalisations_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/canalisations.shp
# Processing ../data_sets/dataset I/RESEAU/canalisations.shp
# Processing ../data_sets/dataset II/A_TRONCON.shp
# Processing ../data_sets/dataset III/M3M/A_TRONCON.shp
# Processing ../data_sets/dataset IV/ass_rassa.shp
# Processing ../data_sets/dataset IV/ReseauMarcheTopo.shp
# Processing ../data_sets/dataset I/EST_OUEST/canalisations_de_branchement_EO.shp
# Processing ../data_sets/dataset I/RESEAU/canalisations_de_branchement.shp
# Processing ../data_sets/dataset II/A_BRANCHEMENT_LINE.shp
# Processing ../data_sets/dataset III/M3M/A_BRANCHEMENT.shp
# Processing ../data_sets/dataset IV/ass_brat.shp
# Processing ../data_sets/dataset I/EST_OUEST/branchements_EO.shp
# Processing ../data_sets/dataset I/RESEAU/branchements.shp
# Processing ../data_sets/dataset II/A_BRANCHEMENT_POINT.shp
# Processing ../data_sets/dataset IV/ass_bran.shp
# Processing ../data_sets/dataset I/EST_OUEST/regards_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/regards_contrat_maera.shp
# Processing ../data_sets/dataset I/RESEAU/regards.shp
# Processing ../data_sets/dataset II/A_REGARD.shp
# Processing ../data_sets/dataset III/M3M/A_REGARD.shp
# Processing ../data_sets/dataset IV/REG.shp
# Processing ../data_sets/dataset I/EST_OUEST/raccords_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/raccords_contrat_maera.shp
# Processing ../data_sets/dataset I/RESEAU/raccords.shp
# Processing ../data_sets/dataset IV/RAC.shp
# Processing ../data_sets/dataset I/EST_OUEST/pompages_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/pompages_contrat_maera.shp
# Processing ../data_sets/dataset I/RESEAU/pompages.shp
# Processing ../data_sets/dataset IV/PMP.shp
# Processing ../data_sets/dataset I/EST_OUEST/station_de_traitement_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/station_de_traitement_contrat_maera.shp
# Processing ../data_sets/dataset I/RESEAU/station_de_traitement.shp
# Processing ../data_sets/dataset IV/TRA.shp
# Processing ../data_sets/dataset I/EST_OUEST/ouvrages_EO.shp
# Processing ../data_sets/dataset I/RESEAU_MAERA/ouvrages_contrat_maera.shp
# Processing ../data_sets/dataset I/RESEAU/ouvrages.shp
# Processing ../data_sets/dataset II/A_OUVRAGE.shp
# Processing ../data_sets/dataset III/M3M/A_OUVRAGE.shp
# Processing ../data_sets/dataset IV/OUV.shp
# Processing ../data_sets/dataset II/A_ACCESSOIRE.shp
# Processing ../data_sets/dataset III/M3M/A_ACCESSOIRE.shp
# Processing ../data_sets/dataset IV/CommuneExploitant.shp
# Processing ../data_sets/dataset IV/recolementEU.shp

# %%
# Data types utils

import datetime
from dateutil.parser import parse
import dateparser
import numpy as np
from collections import Counter

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    
def is_date(s):
    strict_settings = {'STRICT_PARSING': True}
    return bool(dateparser.parse(s, settings=strict_settings))
    
def is_time(s):
    try:
        datetime.datetime.strptime(s, '%H:%M:%S')
        return True
    except ValueError:
        return False
    
def is_datetime(s):
    try:
        datetime.datetime.strptime(s, '%d/%m/%Y %H:%M:%S')
        return True
    except ValueError:
        return False
    
def is_bool(s):
    if s.lower() == 'true' or s.lower() == 'false':
        return True
    else:
        return False
    
def is_null(s):
    if s.lower() == '<null>' or s == None or s.upper() == 'INCONNU':
        return True
    else:
        return False


STRING = 'String'
NUMBER = 'Number'
NULL = 'Null'
DATE = 'Date'
TIME = 'Time'
DATETIME = 'Datetime'
BOOL = 'Bool'
CATEGORICAL = 'Categorical'
UNKNOWN = 'Unknown'

def get_type_of_value(value):
    if is_number(value):
        return NUMBER
    elif is_date(value):
        return DATE
    # elif is_time(value):
    #     return TIME
    # elif is_datetime(value):
    #     return DATETIME
    # elif is_bool(value):
    #     return BOOL
    # elif is_null(value):
    #     return NULL
    else:
        return STRING

# %%
# Get the type from an attribute values list
def get_type(list, threshold=0.9, caterogical_threshold=0.2, categorical_max_values=100, null_values=[None]):
    """Get the type from an attribute values list

    Args:
        list (Any): list of values to be analyzed
        threshold (float, optional): if the number of occurences of a type is greater than the threshold, then it's the type of the attribute. Defaults to 0.9.
        caterogical_threshold (float, optional): number of unique values by the number of elements is less than the threshold, it's an Categorical attribute. Defaults to 0.2.
        categorical_max_values (int, optional): the maximum number that a categorical attribute can have. Defaults to 100.
        null_values (list, optional): list of null values. Defaults to [None].

    Returns:
        [list]: [type, max_value, min_value, values_list]
    """
    
    data_ = np.array(list)
    data_occurence = Counter(data_)
    
    # remove null values
    for key in null_values:
        if key in data_occurence:
            del data_occurence[key]
            
    # nbr of elements
    nbr_of_elemenst = data_occurence.total()
    
    if(nbr_of_elemenst == 0):
        return [UNKNOWN, None, None, None, "0/"+str(len(list))]
    
    # return vars
    type = UNKNOWN
    max_val = None
    min_val = None
    values_list = None
    
    types_dict = {STRING:0, NUMBER:0, NULL:0, DATE:0}
    
    values_count = len(data_occurence)
    
    # this takes a lot of time
    for val,occ in data_occurence.items():
        val_type = get_type_of_value(val)
        types_dict[val_type] += occ
        
        # if the number of occurences of STRING is greater than the (1 - threshold), then it's the type could be STRING or CATEGORICAL
        if val_type == STRING and types_dict[STRING] / nbr_of_elemenst > (1 - threshold):
            type = STRING
            break
        
        # if the number of occurences of a type is greater than the threshold, then it's the type
        if types_dict[val_type] / nbr_of_elemenst > threshold :
            type = val_type
            if val_type == NUMBER:
                numbers = [k for (k,v) in data_occurence.items() if is_number(k)]
                max_val = max(numbers)
                min_val = min(numbers)
            break
    
    
    if nbr_of_elemenst > 0 and (values_count / nbr_of_elemenst) < caterogical_threshold and values_count <= categorical_max_values:
        if type != None:
            type = CATEGORICAL + '-' + type
        else:
            type = CATEGORICAL
            
        values_list = []
        for val,occ in data_occurence.items():
            values_list.append(val)
        
    return [type, max_val, min_val, values_list, str(nbr_of_elemenst)+"/"+str(len(list))]

# %%
# Get the types of all fields in parallel

from concurrent.futures import ProcessPoolExecutor, as_completed

def process_field(fname, fld):
    attr_type, max_val, min_val, values_list, not_null_values = get_type(data[fname][fld], threshold=0.9, caterogical_threshold=0.2, categorical_max_values=10, null_values=['<Nul>', None, 'INCONNU'])
    type = {'type': attr_type, 'max': max_val, 'min': min_val, 'values': values_list, 'not_null_values':not_null_values}
        
    return [fname, fld, type]

fld_types = {}
with ProcessPoolExecutor() as executor:
    futures = []
    for fname in data:
        for fld in data[fname]:
            # print('Processing field {} of file {}'.format(fld, fname))
            futures.append(executor.submit(process_field, fname, fld))
            
    for type in as_completed(futures):
        fname, fld, result = type.result()
        if fname not in fld_types:
            fld_types[fname] = {}
        fld_types[fname][fld] = result

# %%
fld_types_by_file = {}
for fname in fld_types:
    fld_types_by_file[fname] = {}
    for fld in fld_types[fname]:
        fld_types_by_file[fname][fld] = fld_types[fname][fld]

# %%
for file in fld_types_by_file:
    print(file)
    for fld in fld_types_by_file[file]:
        print('\t{}: {}'.format(fld, fld_types_by_file[file][fld]))
# Out:
# dataset I/RESEAU_MAERA/canalisations.shp
# 	BANQUETTE: {'type': 'Categorical-Number', 'max': '1', 'min': '1', 'values': ['1'], 'not_null_values': '186/236'}
# 	OBJECTID: {'type': 'Number', 'max': 74665, 'min': 0, 'values': None, 'not_null_values': '236/236'}
# 	F_ID_NODE: {'type': 'Number', 'max': 102770, 'min': 63745, 'values': None, 'not_null_values': '236/236'}
# 	FFIL: {'type': 'Number', 'max': 999.0, 'min': -2.87, 'values': None, 'not_null_values': '236/236'}
# 	FCHAUSSEE: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '236/236'}
# 	DIMENSIONS: {'type': 'Number', 'max': '999', 'min': '100', 'values': None, 'not_null_values': '236/236'}
# 	FRADIER: {'type': 'Number', 'max': 999.0, 'min': -2.87, 'values': None, 'not_null_values': '236/236'}
# 	ID_ARC: {'type': 'Number', 'max': 102914, 'min': 63536, 'values': None, 'not_null_values': '236/236'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/236'}
# 	LONGUEUR: {'type': 'Number', 'max': 10295.2001953, 'min': 0.2, 'values': None, 'not_null_values': '236/236'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2010/01/01', '2004/01/01', '2011/01/01'], 'not_null_values': '236/236'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['BILICKI-DHOMBRES-OSMO'], 'not_null_values': '101/236'}
# 	NOTES: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EXTRAPOLATION CAM', 'FONTE PUX', 'FORAGE DIRIGE'], 'not_null_values': '29/236'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/236'}
# 	NOM_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RUE DES ACCONIERS', 'RUE DU CHELIA', 'AVENUE DU PROF E ANTONELLI', 'DE CARNON', 'DE LA MER'], 'not_null_values': '111/236'}
# 	OUVRAGE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/236'}
# 	PENTE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/236'}
# 	PENTER: {'type': 'Number', 'max': 55.711, 'min': -59.64, 'values': None, 'not_null_values': '236/236'}
# 	SECT_TRON: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '236/236'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EHTP/SCAM/SADE/SOGEA'], 'not_null_values': '40/236'}
# 	SYMBOL: {'type': 'Categorical-Number', 'max': 0, 'min': 0, 'values': [0], 'not_null_values': '236/236'}
# 	T_ID_NODE: {'type': 'Number', 'max': 102770, 'min': 63745, 'values': None, 'not_null_values': '236/236'}
# 	TCHAUSSEE: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '236/236'}
# 	TFIL: {'type': 'Number', 'max': 999.0, 'min': -3.01, 'values': None, 'not_null_values': '236/236'}
# 	TRADIER: {'type': 'Number', 'max': 999.0, 'min': -4.560000000000001, 'values': None, 'not_null_values': '236/236'}
# 	SURVERSE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3/236'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RTE', 'AV'], 'not_null_values': '63/236'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EMISSAIRE TERRESTRE', 'RACCORDEMENT PALAVAS HIVER', 'RACCORD', 'EMISSAIRE LAGUNAIRE', "CHEMINEE D'EQUILIBRE", 'RACCORDEMENT PALAVAS ETE', 'EMISSAIRE MARITIME', 'RACCORDEMENT DE PEROLS'], 'not_null_values': '90/236'}
# 	GESTION: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PUBLIC', 'SERVITUDE A INSCRIRE'], 'not_null_values': '176/236'}
# 	D_ID_PR: {'type': 'Categorical-Number', 'max': 9423, 'min': 427, 'values': [999, 9423, 427, 429], 'not_null_values': '236/236'}
# 	TYPER: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['UNITAIRE', 'EAUX USEES', 'REJET'], 'not_null_values': '236/236'}
# 	F_FICH_T: {'type': 'Categorical-Number', 'max': 999, 'min': 0, 'values': [999, 0], 'not_null_values': '236/236'}
# 	C_ID_ITV: {'type': 'Categorical-Number', 'max': 999, 'min': 0, 'values': [999, 0], 'not_null_values': '236/236'}
# 	CODCOMM: {'type': 'Categorical-Number', 'max': '340198', 'min': '340129', 'values': ['340172', '340129', '340198'], 'not_null_values': '224/236'}
# 	G_T_EFFE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RESEAU NEUF 2010', 'RESEAU NEUF', 'TRAVAUX EFFECTUES 2011'], 'not_null_values': '87/236'}
# 	TEST: {'type': 'Categorical-Number', 'max': 0, 'min': 0, 'values': [0], 'not_null_values': '236/236'}
# 	E_CODE_T: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RESEAU NEUF 2011'], 'not_null_values': '39/236'}
# 	MAJ: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['03/04/2012', '28/09/2009', '29/09/2009', '21/02/2014'], 'not_null_values': '128/236'}
# 	VERROU: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/236'}
# 	GS_AMONT: {'type': 'Number', 'max': 999.0, 'min': -1.76, 'values': None, 'not_null_values': '236/236'}
# 	GS_AVAL: {'type': 'Number', 'max': 999.0, 'min': -2.4, 'values': None, 'not_null_values': '236/236'}
# 	BRANCHE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['INTERCEPTEUR'], 'not_null_values': '145/236'}
# 	ECOUL: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT', 'TROP PLEIN'], 'not_null_values': '236/236'}
# 	MATERIAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['FONTE', 'PRV', 'BETON', 'PVC'], 'not_null_values': '164/236'}
# 	A_SOURCE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '232/236'}
# 	B_DATE_D: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['JANVIER 2006', 'JUILLET 2006', 'JUIN 2010', '2007', '2009', 'FEVRIER 2014'], 'not_null_values': '185/236'}
# 	COMMUNE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['MONTPELLIER', 'LATTES', 'PALAVAS LES FLOTS', 'MER MEDITTERRANEE', 'PEROLS'], 'not_null_values': '236/236'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '236/236'}
# dataset III/M3M/A_BRANCHEMENT.shp
# 	DIAMETRE: {'type': 'Number', 'max': 800.0, 'min': 0.0, 'values': None, 'not_null_values': '1700/12805'}
# 	MATERIAU: {'type': 'Categorical-Number', 'max': '46013', 'min': '0', 'values': ['46013', '0', '287', '46005', '46001', '46002'], 'not_null_values': '2758/12805'}
# 	COMMUNE: {'type': 'Number', 'max': '34327', 'min': '34057', 'values': None, 'not_null_values': '12805/12805'}
# 	MSLINK: {'type': 'Number', 'max': 76619.0, 'min': 21.0, 'values': None, 'not_null_values': '12805/12805'}
# 	CODE_CONT: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['J3551', 'HorsRccAss', 'J3561'], 'not_null_values': '12805/12805'}
# dataset I/EST_OUEST/canalisations_de_branchement_EO.shp
# 	OBJECTID: {'type': 'Number', 'max': 32965, 'min': 3, 'values': None, 'not_null_values': '1703/1703'}
# 	DIMENSIONS: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1703'}
# 	FCHAUSSEE: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '1703/1703'}
# 	FFIL: {'type': 'Number', 'max': 999.0, 'min': 0.21, 'values': None, 'not_null_values': '1703/1703'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EIFFAGE TP', 'FAURIE', 'ASTRUC', 'FAURIE/BRAULT TP', 'EHTP', 'EHTP/SOGEA/SADE', 'SCAM', 'EHTP/COLAS', 'JOULIE TP'], 'not_null_values': '300/1703'}
# 	FRADIER: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '1703/1703'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1703'}
# 	ID_BRANT: {'type': 'Number', 'max': 14429, 'min': 0, 'values': None, 'not_null_values': '1703/1703'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CABINET CHAPUIS', 'BILICKI-DHOMBRES-OSMO', 'SCP BOTTRAUD-BARBAROUX', 'FAURIE', 'GEOPIC', 'EIFFAGE TP', 'CABINET PAGES', 'FREDERIC BENOIT', 'EPSILON GE'], 'not_null_values': '299/1703'}
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '1703/1703'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1703'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1703/1703'}
# 	TCHAUSSEE: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '1703/1703'}
# 	TFIL: {'type': 'Number', 'max': 9990.0, 'min': 0.0, 'values': None, 'not_null_values': '1703/1703'}
# 	TRADIER: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '1703/1703'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT'], 'not_null_values': '310/1703'}
# 	CODCOMM: {'type': 'Number', 'max': '340337', 'min': '340022', 'values': None, 'not_null_values': '1690/1703'}
# 	MATERIAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PVC', 'POLYETHYLENE', 'FONTE', 'PEHD', 'AMIANTE CIMENT'], 'not_null_values': '447/1703'}
# 	NOTES: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['DONNEE TECHNICIEN TERRAIN', 'PN16', 'PLACEMENT APPROXIMATIF', 'NON OUVERT'], 'not_null_values': '25/1703'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '400/1703'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['ALL', 'PL', 'IMP', 'RUE', 'CHE', 'LOT', 'AV', 'RTE'], 'not_null_values': '327/1703'}
# 	MAJ: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '295/1703'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1703/1703'}
# dataset I/EST_OUEST/branchements_EO.shp
# 	ID_BRAN: {'type': 'Number', 'max': '9975', 'min': '10013', 'values': None, 'not_null_values': '1810/1810'}
# 	CODCOMM: {'type': 'Number', 'max': '340307', 'min': '340022', 'values': None, 'not_null_values': '1810/1810'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'VANNE', 'REFOULEMENT'], 'not_null_values': '305/1810'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RUE', 'PL', 'IMP', 'ALL', 'LOT', 'CHE', 'AV', 'RTE', 'CHEM'], 'not_null_values': '328/1810'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1810/1810'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1810'}
# 	NOTES: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['MISE A LA COTE OCTOBRE 2011'], 'not_null_values': '22/1810'}
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '1810/1810'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['FAURIE', 'SCP BOTTRAUD-BARBAROUX', 'BILICKI-DHOMBRES-OSMO', 'GEOPIC', 'CABINET PAGES', 'EIFFAGE TP', 'CABINET CHAPUIS', 'EPSILON GE', 'FREDERIC BENOIT'], 'not_null_values': '303/1810'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['FAURIE/BRAULT TP', 'ASTRUC', 'FAURIE', 'SCAM', 'EHTP', 'EHTP/SOGEA/SADE', 'EIFFAGE TP', 'EHTP/COLAS', 'JOULIE TP'], 'not_null_values': '295/1810'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1810'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1810'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/1810'}
# 	MAJ: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1639/1810'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '406/1810'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1809/1810'}
# dataset II/A_BRANCHEMENT_LINE.shp
# 	DIAMETRE: {'type': 'Number', 'max': '63', 'min': '0', 'values': None, 'not_null_values': '14320/14320'}
# 	ID_NODE: {'type': 'Number', 'max': 81593, 'min': 21, 'values': None, 'not_null_values': '14320/14320'}
# 	COMMUNE: {'type': 'Number', 'max': '34327', 'min': '34057', 'values': None, 'not_null_values': '14320/14320'}
# 	DATE_POSE: {'type': 'Number', 'max': '2019', 'min': '1999', 'values': None, 'not_null_values': '4395/14320'}
# 	MATERIAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['Amiante-ciment', 'PVC', 'Inconnu', 'Béton', 'Fonte', 'Fonte ductile', 'Autre', 'Polyéthylène'], 'not_null_values': '14320/14320'}
# 	LONGUEUR: {'type': 'Number', 'max': 132.5, 'min': 0.15, 'values': None, 'not_null_values': '14320/14320'}
# 	RESEAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EU', 'Unitaire', 'Prive EU', 'Prive Unitaire', 'EP', 'TRANSFERT-GRAVITAIRE', 'Refoulement ASS'], 'not_null_values': '14320/14320'}
# 	CONTRAT: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['J3551', 'HorsRccAss', 'J3561', 'T5P05'], 'not_null_values': '14320/14320'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '14320/14320'}
# dataset I/RESEAU/canalisations_de_branchement.shp
# 	OBJECTID: {'type': 'Number', 'max': 33924, 'min': 1, 'values': None, 'not_null_values': '3912/3912'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3912/3912'}
# 	DIMENSIONS: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3912'}
# 	ENTREPRISE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '986/3912'}
# 	FCHAUSSEE: {'type': 'Number', 'max': 5010.0, 'min': 0.0, 'values': None, 'not_null_values': '3912/3912'}
# 	FFIL: {'type': 'Number', 'max': 999.0, 'min': -0.47, 'values': None, 'not_null_values': '3912/3912'}
# 	FOURNISSEU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1088/3912'}
# 	FRADIER: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '3912/3912'}
# 	ID_BRANT: {'type': 'Number', 'max': 14538, 'min': 0, 'values': None, 'not_null_values': '3912/3912'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3912'}
# 	MATERIAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PVC', 'POLYPROPYLENE', 'FONTE', 'PEHD'], 'not_null_values': '1430/3912'}
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '3912/3912'}
# 	NUM_VOIE: {'type': 'Number', 'max': '0', 'min': '0', 'values': None, 'not_null_values': '5/3912'}
# 	NOTES: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '17/3912'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1543/3912'}
# 	TCHAUSSEE: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '3912/3912'}
# 	TRADIER: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '3912/3912'}
# 	TFIL: {'type': 'Number', 'max': 999.0, 'min': -0.67, 'values': None, 'not_null_values': '3912/3912'}
# 	TYPE_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '843/3912'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT'], 'not_null_values': '1136/3912'}
# 	CODCOMM: {'type': 'Number', 'max': '340327', 'min': '340057', 'values': None, 'not_null_values': '3628/3912'}
# 	MAJ: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '664/3912'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3912/3912'}
# dataset I/RESEAU/branchements.shp
# 	ID_BRAN: {'type': 'Number', 'max': '9995', 'min': '10233', 'values': None, 'not_null_values': '4173/4173'}
# 	CODCOMM: {'type': 'Number', 'max': '340327', 'min': '340057', 'values': None, 'not_null_values': '4172/4173'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4173/4173'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'VANNE'], 'not_null_values': '1109/4173'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1522/4173'}
# 	TYPE_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '825/4173'}
# 	NOTES: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/4173'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/4173'}
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '4173/4173'}
# 	FOURNISSEU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1094/4173'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/4173'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/4173'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/4173'}
# 	ENTREPRISE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '993/4173'}
# 	MAJ: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3302/4173'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4123/4173'}
# dataset I/RESEAU_MAERA/regards_contrat_maera.shp
# 	ID_NODE: {'type': 'Number', 'max': '99684', 'min': '102750', 'values': None, 'not_null_values': '96/96'}
# 	CODCOMM: {'type': 'Categorical-Number', 'max': '340198', 'min': '340129', 'values': ['340172', '340129', '340198'], 'not_null_values': '96/96'}
# 	COMMUNE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['MONTPELLIER', 'LATTES', 'PEROLS'], 'not_null_values': '96/96'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['UNITAIRE', 'REGARD DE VISITE SIMPLE', 'REGARD NON TYPE'], 'not_null_values': '96/96'}
# 	TYPEREG: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/96'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RTE', 'AV'], 'not_null_values': '11/96'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2007/01/01', '2010/01/01', '2011/01/01'], 'not_null_values': '96/96'}
# 	NOTES: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	DATE_REC: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	DEBITMETRE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	MATERIAU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/96'}
# 	DIAMETRE: {'type': 'Categorical-Number', 'max': '999', 'min': '999', 'values': ['999'], 'not_null_values': '10/96'}
# 	ID_TR: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	TAMP_ANOM: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/96'}
# 	PROF_RADIE: {'type': 'Number', 'max': '5.61', 'min': '0', 'values': None, 'not_null_values': '96/96'}
# 	CADRE_ANOM: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	NOM_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['AVENUE DU PROF E ANT', 'RUE DU CHELIA', 'RUE DES ACCONIERS', 'DE CARNON', 'DE LA MER'], 'not_null_values': '59/96'}
# 	ENTREPRISE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/96'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['BILICKI-DHOMBRES-OSMO', 'BILICKI DHOMBRES OSMO'], 'not_null_values': '12/96'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	CUN_ANOM: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/96'}
# 	PARTICULA: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['REFOULEMENT'], 'not_null_values': '10/96'}
# 	MAJ: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAS', '29/09/2009', '03/04/2012', '21/02/2014'], 'not_null_values': '96/96'}
# 	PRO_RADIER: {'type': 'Number', 'max': '3.69', 'min': '0', 'values': None, 'not_null_values': '96/96'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '96/96'}
# dataset II/A_BRANCHEMENT_POINT.shp
# 	COMMUNE: {'type': 'Number', 'max': '34327', 'min': '34057', 'values': None, 'not_null_values': '14320/14320'}
# 	ID_NODE: {'type': 'Number', 'max': 81593, 'min': 21, 'values': None, 'not_null_values': '14320/14320'}
# 	DIAMETRE: {'type': 'Number', 'max': '63', 'min': '0', 'values': None, 'not_null_values': '14320/14320'}
# 	MATERIAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['Amiante-ciment', 'PVC', 'Inconnu', 'Béton', 'Fonte', 'Fonte ductile', 'Autre', 'Polyéthylène'], 'not_null_values': '14320/14320'}
# 	RESEAU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EU', 'Unitaire', 'Prive EU', 'Prive Unitaire', 'EP', 'TRANSFERT-GRAVITAIRE', 'Refoulement ASS'], 'not_null_values': '14320/14320'}
# 	DATE_POSE: {'type': 'Number', 'max': '2019', 'min': '1999', 'values': None, 'not_null_values': '4395/14320'}
# 	LONGUEUR: {'type': 'Number', 'max': 132.5, 'min': 0.15, 'values': None, 'not_null_values': '14320/14320'}
# 	CONTRAT: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['J3551', 'HorsRccAss', 'J3561', 'T5P05'], 'not_null_values': '14320/14320'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '14320/14320'}
# dataset III/M3M/A_TRONCON.shp
# 	MSLINK: {'type': 'Number', 'max': 547148.0, 'min': 2776.0, 'values': None, 'not_null_values': '35535/35535'}
# 	DIAMETRE: {'type': 'Number', 'max': 4000.0, 'min': 0.0, 'values': None, 'not_null_values': '35535/35535'}
# 	COMMUNE: {'type': 'Number', 'max': '34327', 'min': '34057', 'values': None, 'not_null_values': '35535/35535'}
# 	MATERIAU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '35535/35535'}
# 	CODE_CONT: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['J3551', 'HorsRccAss', 'J3601', 'J3561'], 'not_null_values': '35535/35535'}
# 	MOTRICITE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT'], 'not_null_values': '34824/35535'}
# 	long: {'type': 'Number', 'max': 10108.0492362, 'min': 0.0, 'values': None, 'not_null_values': '35535/35535'}
# 	ANNEE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '23932/35535'}
# dataset IV/ass_bran.shp
# 	angle: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '9526/9526'}
# 	codepost: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/9526'}
# 	commune: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9361/9526'}
# 	cote: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 999.0], 'not_null_values': '9526/9526'}
# 	date_pose: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '9526/9526'}
# 	diametre: {'type': 'Number', 'max': '999', 'min': '125', 'values': None, 'not_null_values': '2978/9526'}
# 	entreprise: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4442/9526'}
# 	fournisseu: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4735/9526'}
# 	id_bran: {'type': 'Number', 'max': 18352, 'min': 3, 'values': None, 'not_null_values': '9526/9526'}
# 	id_tron: {'type': 'Number', 'max': 108426, 'min': 0, 'values': None, 'not_null_values': '9526/9526'}
# 	implant: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/9526'}
# 	materiau: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PRV', 'PVC', 'BETON', 'FONTE', 'POLYPROPYLENE', 'PEHD', 'FONT', 'PP'], 'not_null_values': '1217/9526'}
# 	nom_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4965/9526'}
# 	notes: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '349/9526'}
# 	num_voie: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/9526'}
# 	symbol: {'type': 'Categorical-Number', 'max': 0, 'min': 0, 'values': [0], 'not_null_values': '9526/9526'}
# 	type: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'VANNE', 'REFOULEMENT', 'UNITAIRE'], 'not_null_values': '4530/9526'}
# 	type_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3023/9526'}
# 	codcomm: {'type': 'Number', 'max': '34090', 'min': '30090', 'values': None, 'not_null_values': '9424/9526'}
# 	maj: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '8372/9526'}
# 	numero: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9475/9526'}
# dataset I/EST_OUEST/raccords_EO.shp
# 	ID_NODE: {'type': 'Number', 'max': '97908', 'min': '100195', 'values': None, 'not_null_values': '95/95'}
# 	CODCOMM: {'type': 'Categorical-Number', 'max': '340295', 'min': '340022', 'values': ['340244', '340027', '340022', '340088', '340295', '340095', '340087'], 'not_null_values': '92/95'}
# 	COMMUNE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['SAINT BRES', 'BEAULIEU', 'BAILLARGUES', 'SAINT-BRES', 'MURVIEL LES MONTPELLIER', 'PIGNAN', 'COURNONTERRAL', 'SAUSSAN', 'FABREGUES', 'COURNONSEC'], 'not_null_values': '95/95'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PIQUAGE', 'COUDE', 'VANNE', 'CONE DE REDUCTION', 'TE', 'VENTOUSE', 'MANCHON', 'CLAPET', 'JOINT DE VERROUILLAGE', "BRIDE D'EMBOITEMENT"], 'not_null_values': '89/95'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '31/95'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CHE', 'RTE', 'AV', 'RUE'], 'not_null_values': '25/95'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2012/02/15', '2011/04/01', '2012/01/01', '2010/07/30', '2009/01/01', '2011/09/01', '2012/02/01'], 'not_null_values': '95/95'}
# 	NOTES: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	DATE_REC: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	ID_TR: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '95/95'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['FAURIE', 'FAURIE/BEC', 'SOGEA', 'ASTRUC', 'JOULIE TP'], 'not_null_values': '87/95'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GEOPIC', 'BILICKI-DHOMBRES-OSMO', 'CABINET PAGES'], 'not_null_values': '65/95'}
# 	MAJ: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAS', '20/07/2012', '30/08/2012', '26/10/2012', '06/07/2012', '10/07/2012'], 'not_null_values': '94/95'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/95'}
# dataset I/RESEAU_MAERA/raccords_contrat_maera.shp
# 	ID_NODE: {'type': 'Number', 'max': '99674', 'min': '102716', 'values': None, 'not_null_values': '106/106'}
# 	CODCOMM: {'type': 'Categorical-Number', 'max': '340198', 'min': '340090', 'values': ['340129', '340090', '340198'], 'not_null_values': '98/106'}
# 	COMMUNE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['LATTES', 'PALAVAS LES FLOTS', 'MONTPELLIER', 'PEROLS'], 'not_null_values': '106/106'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['COUDE', 'TE', 'BUSE'], 'not_null_values': '65/106'}
# 	NOM_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['DE CARNON', 'DE LA MER'], 'not_null_values': '44/106'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RTE', 'AV'], 'not_null_values': '44/106'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2010/01/01', '2011/01/01'], 'not_null_values': '106/106'}
# 	NOTES: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '29/106'}
# 	DATE_REC: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# 	ID_TR: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '106/106'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EHTP/SCAM/SADE/SOGEA'], 'not_null_values': '21/106'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['BILICKI-DHOMBRES-OSMO'], 'not_null_values': '65/106'}
# 	MAJ: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAS', '03/04/2012', '21/02/2014'], 'not_null_values': '105/106'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/106'}
# dataset I/RESEAU/raccords.shp
# 	ID_NODE: {'type': 'Number', 'max': '99034', 'min': '100057', 'values': None, 'not_null_values': '250/250'}
# 	CODCOMM: {'type': 'Categorical-Number', 'max': '340327', 'min': '340057', 'values': ['340172', '340129', '340270', '340116', '340327', '340057', '340198', '340077', '340090', '340169'], 'not_null_values': '249/250'}
# 	COMMUNE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['MONTPELLIER', 'LATTES', 'SAINT JEAN DE VEDAS', 'GRABELS', 'VENDARGUES', 'CASTELNAU LE LEZ', 'PEROLS', 'CLAPIERS', 'LE CRES', 'MONTFERRIER SUR LEZ'], 'not_null_values': '249/250'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PIQUAGE', 'COUDE', 'TE', 'CÔNE DE REDUCTION', 'MANCHON', 'PLAQUE PLEINE'], 'not_null_values': '72/250'}
# 	NOM_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RD 172', 'DE CHOLET', 'MARCEL PAGNOL', 'RD 65', 'CHARLES DE GAULLE', 'DES LACS'], 'not_null_values': '58/250'}
# 	TYPE_VOIE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RTE', 'RUE', 'PL', 'ALL'], 'not_null_values': '53/250'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2008/01/01', '2005/01/01', '2011/07/20', '2008/04/01', '2010/11/19', '2011/01/01', '2008/06/01', '2008/11/01', '2010/01/01'], 'not_null_values': '250/250'}
# 	NOTES: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/250'}
# 	DATE_REC: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	ID_TR: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	ENTREPRISE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EHTP', 'EHTP/SOGEA/SADE', "OC'INFRA", 'FAURIE', 'EUROVIA', 'SCAM', 'SOCAFL', 'SOGEA', 'SPIE'], 'not_null_values': '82/250'}
# 	FOURNISSEU: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['BILICKI-DHOMBRES-OSMO', 'EUROVIA', 'CABINET PAGES'], 'not_null_values': '86/250'}
# 	MAJ: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAS', '08/08/2012', '19/06/2012', '20/07/2012', '26/06/2012', '05/07/2012', '26/03/2013'], 'not_null_values': '222/250'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/250'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '250/250'}
# dataset IV/RAC.shp
# 	objectid: {'type': 'Number', 'max': 273790, 'min': 64, 'values': None, 'not_null_values': '427/427'}
# 	angle: {'type': 'Number', 'max': 178.49, 'min': 0.0, 'values': None, 'not_null_values': '427/427'}
# 	id_node: {'type': 'Number', 'max': 108033, 'min': 5775, 'values': None, 'not_null_values': '427/427'}
# 	symbol: {'type': 'Categorical-Number', 'max': 6000, 'min': 0, 'values': [999, 0, 6000, 320], 'not_null_values': '427/427'}
# 	type: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAC', 'REG'], 'not_null_values': '427/427'}
# 	codcomm: {'type': 'Number', 'max': '999999', 'min': '340022', 'values': None, 'not_null_values': '420/427'}
# 	cheminee: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	codepost: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	date_pose: {'type': 'Number', 'max': '29991231000000', 'min': '20050101000000', 'values': None, 'not_null_values': '427/427'}
# 	commune: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '413/427'}
# 	entreprise: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '228/427'}
# 	implant: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	fournisseu: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '260/427'}
# 	nom_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '166/427'}
# 	num_voie: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	tampon: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	type_voie: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RUE', 'AV', 'CHE', 'RTE', 'ALL', 'PL', 'IMP'], 'not_null_values': '129/427'}
# 	maj: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '386/427'}
# 	photo: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/427'}
# 	numero: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '427/427'}
# 	notes: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '47/427'}
# dataset I/EST_OUEST/pompages_EO.shp
# 	ID_NODE: {'type': 'Number', 'max': '99884', 'min': '100741', 'values': None, 'not_null_values': '79/79'}
# 	CODCOMM: {'type': 'Number', 'max': '340337', 'min': '340022', 'values': None, 'not_null_values': '78/79'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '79/79'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['POSTE DE RELEVAGE', 'POSTE DE REFOULEMENT'], 'not_null_values': '32/79'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '19/79'}
# 	TYPE_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '7/79'}
# 	DATE_POSE: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['2999/12/31', '2010/07/01', '2007/01/01', '2011/04/01', '2010/07/30', '2010/01/01', '2009/01/01', '2011/09/01'], 'not_null_values': '79/79'}
# 	NOTES: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/79'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/79'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '79/79'}
# 	ENTREPRISE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '16/79'}
# 	FOURNISSEU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '10/79'}
# 	MAJ: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['RAS', '26/10/2012', '10/07/2012', '30/08/2012', '12/09/2012', '19/04/2012', '06/07/2012'], 'not_null_values': '78/79'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/79'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/79'}
# 	NBPOMPES: {'type': 'Categorical-Number', 'max': '4', 'min': '0', 'values': ['0', '2', '4', '3'], 'not_null_values': '79/79'}
# 	B_NMTH: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	B_NMH: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	B_HMNORMAL: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	B_NMB: {'type': 'Categorical-Number', 'max': '0', 'min': '0', 'values': ['0'], 'not_null_values': '79/79'}
# 	B_NMTB: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	P1_MARQUE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '10/79'}
# 	P1_TYPE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9/79'}
# 	P1_DEBIT: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 30.0, 89.0, 999.0, 62.0, 28.0, 30.02, 10.8, 12.6, 250.0], 'not_null_values': '79/79'}
# 	P1_PUISSAN: {'type': 'Categorical-Number', 'max': 20.0, 'min': 0.0, 'values': [0.0, 3.99, 3.2, 20.0, 11.0, 1.5, 0.75], 'not_null_values': '79/79'}
# 	P1_HMT: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 12.0, 5.7, 999.0, 33.02, 14.5, 9.6, 15.6, 16.8], 'not_null_values': '79/79'}
# 	P2_MARQUE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9/79'}
# 	P2_TYPE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '8/79'}
# 	P2_DEBIT: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 89.0, 999.0, 62.0, 28.0, 30.02, 10.8, 12.6, 331.0], 'not_null_values': '79/79'}
# 	P2_PUISSAN: {'type': 'Categorical-Number', 'max': 20.0, 'min': 0.0, 'values': [0.0, 3.2, 20.0, 11.0, 1.5, 0.75], 'not_null_values': '79/79'}
# 	P2_HMT: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 5.7, 999.0, 33.02, 14.5, 9.55, 15.6, 5.8], 'not_null_values': '79/79'}
# 	P3_MARQUE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/79'}
# 	P3_PUISSAN: {'type': 'Categorical-Number', 'max': 20.0, 'min': 0.0, 'values': [0.0, 20.0], 'not_null_values': '79/79'}
# 	P3_DEBIT: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	P3_HMT: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	TELESURV: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '7/79'}
# 	DEBIT: {'type': 'Categorical-Number', 'max': 0.0, 'min': 0.0, 'values': [0.0], 'not_null_values': '79/79'}
# 	A_SOURCE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '24/79'}
# 	POMPE: {'type': 'Number', 'max': '2', 'min': '2', 'values': None, 'not_null_values': '1/79'}
# 	TROPPLEIN: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI', 'NON'], 'not_null_values': '14/79'}
# 	GESTION: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PRIVE', 'PUBLIC'], 'not_null_values': '59/79'}
# 	EQUIPEMENT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/79'}
# 	B_DATE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '25/79'}
# 	B_PROFONDE: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 4.0, 5.55, 999.0, 5.2], 'not_null_values': '79/79'}
# 	B_SURFACE: {'type': 'Categorical-Number', 'max': 999.0, 'min': 0.0, 'values': [0.0, 2.0, 13.8, 999.0], 'not_null_values': '79/79'}
# 	GEOMETRIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9/79'}
# 	H2S: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/79'}
# 	CHAMBRE_V: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '9/79'}
# 	B_GENIECIV: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '7/79'}
# 	CLOTURE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '5/79'}
# 	DEBIT_M3_H: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '15/79'}
# 	PANIER_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '7/79'}
# 	P_ULTRASON: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '7/79'}
# 	P_POIRES: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '6/79'}
# 	POP_RACCOR: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '6/79'}
# 	VOLUME: {'type': 'Categorical-Number', 'max': 0.2, 'min': 0.0, 'values': [0.0, 0.2], 'not_null_values': '79/79'}
# 	GRILLE_A: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '8/79'}
# 	P3_TYPE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/79'}
# dataset I/RESEAU_MAERA/pompages_contrat_maera.shp
# 	ID_NODE: {'type': 'Number', 'max': '93798', 'min': '102751', 'values': None, 'not_null_values': '3/3'}
# 	CODCOMM: {'type': 'Number', 'max': '340198', 'min': '340172', 'values': None, 'not_null_values': '3/3'}
# 	COMMUNE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/3'}
# 	NOM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	TYPE_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '3/3'}
# 	NOTES: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	SOURCE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	TYPE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/3'}
# 	ENTREPRISE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	FOURNISSEU: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3/3'}
# 	OBSERVATIO: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	NBPOMPES: {'type': 'Number', 'max': '0', 'min': '0', 'values': None, 'not_null_values': '3/3'}
# 	B_NMTH: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	B_NMH: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	MAJ: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3/3'}
# 	B_HMNORMAL: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	B_NMTB: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P1_MARQUE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P1_TYPE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P1_DEBIT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P1_PUISSAN: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P1_HMT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P2_MARQUE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P2_TYPE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P2_DEBIT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P2_PUISSAN: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P2_HMT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P3_MARQUE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P3_TYPE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P3_PUISSAN: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P3_DEBIT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	P3_HMT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	TELESURV: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	DEBIT: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	B_NMB: {'type': 'Number', 'max': '0', 'min': '0', 'values': None, 'not_null_values': '3/3'}
# 	POMPE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	TROPPLEIN: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/3'}
# 	A_SOURCE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/3'}
# 	EQUIPEMENT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	GESTION: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3/3'}
# 	B_PROFONDE: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	B_SURFACE: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	GEOMETRIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/3'}
# 	B_DATE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/3'}
# 	CHAMBRE_V: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	H2S: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/3'}
# 	CLOTURE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	DEBIT_M3_H: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	PANIER_D: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P_ULTRASON: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	P_POIRES: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	POP_RACCOR: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	VOLUME: {'type': 'Number', 'max': 0.0, 'min': 0.0, 'values': None, 'not_null_values': '3/3'}
# 	GRILLE_A: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/3'}
# 	B_GENIECIV: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/3'}
# dataset IV/ass_brat.shp
# 	codepost: {'type': 'Categorical-Number', 'max': '999', 'min': '0', 'values': ['34000', '0', '999'], 'not_null_values': '61/9288'}
# 	commune: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9202/9288'}
# 	diametre: {'type': 'Number', 'max': '999', 'min': '0', 'values': None, 'not_null_values': '5898/9288'}
# 	entreprise: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4509/9288'}
# ...
# 	DATE_POSE: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '33019/33019'}
# 	DIMENSIONS: {'type': 'Number', 'max': '999', 'min': '100', 'values': None, 'not_null_values': '32950/33019'}
# 	ECOUL: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT', 'TROP PLEIN'], 'not_null_values': '33019/33019'}
# 	ENTREPRISE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1271/33019'}
# 	F_ID_NODE: {'type': 'Number', 'max': 102660, 'min': 4562, 'values': None, 'not_null_values': '33019/33019'}
# 	FCHAUSSEE: {'type': 'Number', 'max': 3519.0, 'min': -46.3011983, 'values': None, 'not_null_values': '33019/33019'}
# 	FFIL: {'type': 'Number', 'max': 999.0, 'min': -292.0, 'values': None, 'not_null_values': '33019/33019'}
# 	FOURNISSEU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1932/33019'}
# 	FRADIER: {'type': 'Number', 'max': 2833.18672191, 'min': -46.3011983, 'values': None, 'not_null_values': '33019/33019'}
# 	GESTION: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PUBLIC', 'SERVITUDE A INSCRIRE', 'PRIVE', 'A VERIFIER', 'PARCELLE PRIVEE MAIS TETE OU ACCES SANS CONTRAINTE', 'PASSAGE FUTUR EN DOMAINE PUBLIC', 'SERVITUDE A INSCRIRE AU PLU', 'PRIVE AVEC SERVITUDE'], 'not_null_values': '16652/33019'}
# 	ID_ARC: {'type': 'Number', 'max': 102804, 'min': 5382, 'values': None, 'not_null_values': '33019/33019'}
# 	IMPLANT: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/33019'}
# 	LONGUEUR: {'type': 'Number', 'max': 1875.59997559, 'min': 0.2, 'values': None, 'not_null_values': '33019/33019'}
# 	MATERIAU: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '17972/33019'}
# 	NOTES: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1855/33019'}
# 	NUM_VOIE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/33019'}
# 	NOM_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '16506/33019'}
# 	OUVRAGE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/33019'}
# 	PENTE: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/33019'}
# 	PENTER: {'type': 'Number', 'max': 1198.4, 'min': -1197.487, 'values': None, 'not_null_values': '33019/33019'}
# 	SECT_TRON: {'type': 'Categorical-Number', 'max': 0.13, 'min': 0.0, 'values': [0.0, 0.03, 0.13, 0.02, 0.07], 'not_null_values': '33019/33019'}
# 	SURVERSE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/33019'}
# 	SYMBOL: {'type': 'Categorical-Number', 'max': 0, 'min': 0, 'values': [0], 'not_null_values': '33019/33019'}
# 	T_ID_NODE: {'type': 'Number', 'max': 102660, 'min': 4562, 'values': None, 'not_null_values': '33019/33019'}
# 	TCHAUSSEE: {'type': 'Number', 'max': 5360.0, 'min': -46.3011983, 'values': None, 'not_null_values': '33019/33019'}
# 	TFIL: {'type': 'Number', 'max': 999.0, 'min': -292.0, 'values': None, 'not_null_values': '33019/33019'}
# 	TRADIER: {'type': 'Number', 'max': 1970.38561527, 'min': -46.3011983, 'values': None, 'not_null_values': '33019/33019'}
# 	TYPE: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CIRCULAIRE', 'RACCORDEMENT DE CARNON', 'BRANCHEMENT', "CHEMINEE D'EQUILIBRE", 'BYPASS', 'RACCORDEMENT PALAVAS HIVER', 'OVOIDE', 'RECTANGULAIRE'], 'not_null_values': '583/33019'}
# 	TYPE_VOIE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1215/33019'}
# 	TYPER: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EAUX USEES', 'UNITAIRE'], 'not_null_values': '33018/33019'}
# 	B_DATE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '32851/33019'}
# 	D_ID_PR: {'type': 'Number', 'max': 281206, 'min': 0, 'values': None, 'not_null_values': '33019/33019'}
# 	F_FICH_T: {'type': 'Number', 'max': 999, 'min': 0, 'values': None, 'not_null_values': '33019/33019'}
# 	G_T_EFFE: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '20859/33019'}
# 	C_ID_ITV: {'type': 'Number', 'max': 999, 'min': 0, 'values': None, 'not_null_values': '33018/33019'}
# 	CODCOMM: {'type': 'Number', 'max': '340327', 'min': '340057', 'values': None, 'not_null_values': '32925/33019'}
# 	E_CODE_T: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['TRAVAUX PRECONISES', '999', 'TRONCON A SURVEILLER', 'TRAVAUX PRECONISES URGENCE 3'], 'not_null_values': '1072/33019'}
# 	TEST: {'type': 'Categorical-Number', 'max': 999, 'min': 0, 'values': [0, 999], 'not_null_values': '33019/33019'}
# 	MAJ: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '2248/33019'}
# 	A_SOURCE_D: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '32985/33019'}
# 	VERROU: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/33019'}
# 	GS_AMONT: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '750/33019'}
# 	GS_AVAL: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '750/33019'}
# 	NUMERO: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '33019/33019'}
# dataset IV/REG.shp
# 	objectid: {'type': 'Number', 'max': 274968, 'min': 1, 'values': None, 'not_null_values': '45411/45411'}
# 	angle: {'type': 'Number', 'max': 359.16, 'min': 0.0, 'values': None, 'not_null_values': '45411/45411'}
# 	id_node: {'type': 'Number', 'max': 108113, 'min': 1062, 'values': None, 'not_null_values': '45411/45411'}
# 	symbol: {'type': 'Number', 'max': 108829, 'min': 0, 'values': None, 'not_null_values': '45411/45411'}
# 	type: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['REG'], 'not_null_values': '45411/45411'}
# 	codcomm: {'type': 'Number', 'max': '340337', 'min': '30227', 'values': None, 'not_null_values': '44745/45411'}
# 	cheminee: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1/45411'}
# 	codepost: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/45411'}
# 	commune: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '45338/45411'}
# 	date_pose: {'type': 'Number', 'max': '29991231000000', 'min': '20000101000000', 'values': None, 'not_null_values': '45401/45411'}
# 	debitmetre: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/45411'}
# 	entreprise: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4028/45411'}
# 	fournisseu: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '10176/45411'}
# 	implant: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CHAUSSEE', 'TERRAIN NATUREL', 'TROTTOIR', 'TRAVAUX', 'PRIVE', 'MONTPELLIER', 'RUISSEAU', 'MUR', 'ECOLE'], 'not_null_values': '10879/45411'}
# 	nom_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '23650/45411'}
# 	notes: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1416/45411'}
# 	num_voie: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/45411'}
# 	tampon: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['ROND', 'CARRE', '800', 'RECTANGLE', 'CLL_REG_3002301', 'CLL_REG_3002300', 'CLL_REG_3002302'], 'not_null_values': '9985/45411'}
# 	type_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3429/45411'}
# 	mslink: {'type': 'Number', 'max': 28247.0, 'min': 0.0, 'values': None, 'not_null_values': '45225/45411'}
# 	z_tampon: {'type': 'Number', 'max': 736905.08, 'min': 0.0, 'values': None, 'not_null_values': '45225/45411'}
# 	prof_radie: {'type': 'Number', 'max': 735005.52, 'min': 0.0, 'values': None, 'not_null_values': '45225/45411'}
# 	pro_radier: {'type': 'Number', 'max': 735005.52, 'min': 0.0, 'values': None, 'not_null_values': '45225/45411'}
# 	x_tampon: {'type': 'Number', 'max': 78402875.206, 'min': 0.0, 'values': None, 'not_null_values': '45399/45411'}
# 	y_tampon: {'type': 'Number', 'max': 629205044.145, 'min': 0.0, 'values': None, 'not_null_values': '45399/45411'}
# 	typesect: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CIRCUL'], 'not_null_values': '763/45411'}
# 	particula: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '9719/45411'}
# 	typereg: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3086/45411'}
# 	materiau: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '18243/45411'}
# 	cun_anom: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '349/45411'}
# 	tamp_anom: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '6947/45411'}
# 	cadre_anom: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '53/45411'}
# 	test: {'type': 'Number', 'max': '99999', 'min': '0', 'values': None, 'not_null_values': '33706/45411'}
# 	maj: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '44627/45411'}
# 	coordonnee: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/45411'}
# 	diametre: {'type': 'Number', 'max': '999', 'min': '0.58', 'values': None, 'not_null_values': '44643/45411'}
# 	forme: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['CARRE', 'ROND', 'INCONNUE', 'RECTANGLE', 'TE', 'carre', 'CIRCULAIRE'], 'not_null_values': '5707/45411'}
# 	photo: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '6605/45411'}
# 	numero: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '45219/45411'}
# dataset IV/ass_rassa.shp
# 	banquette: {'type': 'Categorical-Date', 'max': None, 'min': None, 'values': ['3M'], 'not_null_values': '8000/47059'}
# 	branche: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['INTERCEPTEUR', 'INTERCEPTEUR EST'], 'not_null_values': '585/47059'}
# 	codepost: {'type': 'Number', 'max': '34179', 'min': '34000', 'values': None, 'not_null_values': '8/47059'}
# 	commune: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '47030/47059'}
# 	date_pose: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '47050/47059'}
# 	dimensions: {'type': 'Number', 'max': '999', 'min': '100', 'values': None, 'not_null_values': '47002/47059'}
# 	ecoul: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['GRAVITAIRE', 'REFOULEMENT', 'TROP PLEIN', 'EN ATTENTE CONFORMITE'], 'not_null_values': '47034/47059'}
# 	entreprise: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '4385/47059'}
# 	f_id_node: {'type': 'Number', 'max': 108112, 'min': 0, 'values': None, 'not_null_values': '47059/47059'}
# 	fchaussee: {'type': 'Number', 'max': 48436.2899181, 'min': -813.93397999, 'values': None, 'not_null_values': '47059/47059'}
# 	ffil: {'type': 'Number', 'max': 48433.1599181, 'min': -292.0, 'values': None, 'not_null_values': '47059/47059'}
# 	fournisseu: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '11063/47059'}
# 	gestion: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['PUBLIC', 'PRIVE', 'PARCELLE PRIVEE MAIS TETE OU ACCES SANS CONTRAINTE', 'PASSAGE FUTUR EN DOMAINE PUBLIC', 'PRIVE AVEC SERVITUDE'], 'not_null_values': '47034/47059'}
# 	id_arc: {'type': 'Number', 'max': 108430, 'min': 1062, 'values': None, 'not_null_values': '47059/47059'}
# 	implant: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '2/47059'}
# 	longueur: {'type': 'Number', 'max': 10295.2001953, 'min': 0.2, 'values': None, 'not_null_values': '47059/47059'}
# 	materiau: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '33622/47059'}
# 	notes: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3833/47059'}
# 	num_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '10/47059'}
# 	fradier: {'type': 'Number', 'max': 48433.1599181, 'min': -748.34028641, 'values': None, 'not_null_values': '47059/47059'}
# 	ouvrage: {'type': 'Unknown', 'max': None, 'min': None, 'values': None, 'not_null_values': '0/47059'}
# 	pente: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '18/47059'}
# 	penter: {'type': 'Number', 'max': 1245.287, 'min': -1344.443, 'values': None, 'not_null_values': '47059/47059'}
# 	sect_tron: {'type': 'Number', 'max': 999.0, 'min': 0.0, 'values': None, 'not_null_values': '47059/47059'}
# 	surverse: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '6/47059'}
# 	symbol: {'type': 'Categorical-Number', 'max': 0, 'min': 0, 'values': [0], 'not_null_values': '47059/47059'}
# 	t_id_node: {'type': 'Number', 'max': 108113, 'min': 0, 'values': None, 'not_null_values': '47059/47059'}
# 	tchaussee: {'type': 'Number', 'max': 155488.60182, 'min': -813.93397999, 'values': None, 'not_null_values': '47059/47059'}
# 	tfil: {'type': 'Number', 'max': 155488.60182, 'min': -292.0, 'values': None, 'not_null_values': '47059/47059'}
# 	tradier: {'type': 'Number', 'max': 155488.60182, 'min': -51.98641514, 'values': None, 'not_null_values': '47059/47059'}
# 	type: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '6626/47059'}
# 	type_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '3771/47059'}
# 	typer: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['EAUX USEES', 'UNITAIRE', 'SEPARATIF-UNITAIRE', 'REJET'], 'not_null_values': '46894/47059'}
# 	b_date_d: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '46292/47059'}
# 	d_id_pr: {'type': 'Number', 'max': 9701007, 'min': 0, 'values': None, 'not_null_values': '47059/47059'}
# 	f_fich_t: {'type': 'Number', 'max': 999, 'min': 0, 'values': None, 'not_null_values': '47059/47059'}
# 	g_t_effe: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '28174/47059'}
# 	c_id_itv: {'type': 'Number', 'max': 9999, 'min': 0, 'values': None, 'not_null_values': '47059/47059'}
# 	codcomm: {'type': 'Number', 'max': '34227', 'min': '300077', 'values': None, 'not_null_values': '46922/47059'}
# 	e_code_t: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1653/47059'}
# 	test: {'type': 'Categorical-Number', 'max': 1000, 'min': 0, 'values': [0, 1000, 999], 'not_null_values': '47059/47059'}
# 	maj: {'type': 'Date', 'max': None, 'min': None, 'values': None, 'not_null_values': '12688/47059'}
# 	a_source_d: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '46933/47059'}
# 	verrou: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['OUI'], 'not_null_values': '19/47059'}
# 	nom_voie: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '20378/47059'}
# 	id_doss_it: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1593/47059'}
# 	gs_amont: {'type': 'Number', 'max': 999.0, 'min': -1.76, 'values': None, 'not_null_values': '47059/47059'}
# 	gs_aval: {'type': 'Number', 'max': 999.0, 'min': -2.4, 'values': None, 'not_null_values': '47059/47059'}
# 	long_cana: {'type': 'Number', 'max': 2300.0, 'min': 0.0, 'values': None, 'not_null_values': '47059/47059'}
# 	larg_cana: {'type': 'Number', 'max': 2200.0, 'min': 0.0, 'values': None, 'not_null_values': '47059/47059'}
# 	precision: {'type': 'Categorical-String', 'max': None, 'min': None, 'values': ['C', 'A', 'N', 'B'], 'not_null_values': '9172/47059'}
# 	st_length_: {'type': 'Number', 'max': 10300.1285796, 'min': 0.200462332543, 'values': None, 'not_null_values': '47059/47059'}
# 	itv: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '1463/47059'}
# 	numero: {'type': 'String', 'max': None, 'min': None, 'values': None, 'not_null_values': '47059/47059'}

# %%
# Nbr of null attributes by file
for comp,files in comp_file_dict.items():
    print(comp)
    for file in files:
        null_count = 0
        shapefile = file + '.shp'
        for fld in fld_types_by_file[shapefile]:
            if fld_types_by_file[shapefile][fld]['type'] == 'Unknown':
                null_count += 1
        print('\t{}: {} by {}'.format(file.removesuffix('/' + file.split('/')[-1]), null_count, len(fld_types_by_file[shapefile])))
# Out:
# Pipe
# 	dataset I/EST_OUEST: 6 by 48
# 	dataset I/RESEAU_MAERA: 5 by 48
# 	dataset I/RESEAU: 6 by 48
# 	dataset II: 0 by 15
# 	dataset III/M3M: 0 by 8
# 	dataset IV: 1 by 54
# 	dataset IV: 5 by 55
# Service Line
# 	dataset I/EST_OUEST: 3 by 23
# 	dataset I/RESEAU: 3 by 23
# 	dataset II: 0 by 9
# 	dataset III/M3M: 0 by 5
# 	dataset IV: 1 by 26
# Connection Point
# 	dataset I/EST_OUEST: 4 by 16
# 	dataset I/RESEAU: 5 by 16
# 	dataset II: 0 by 9
# 	dataset IV: 3 by 21
# Manhole
# 	dataset I/EST_OUEST: 6 by 28
# 	dataset I/RESEAU_MAERA: 10 by 28
# 	dataset I/RESEAU: 6 by 28
# 	dataset II: 0 by 14
# 	dataset III/M3M: 0 by 7
# 	dataset IV: 4 by 39
# Fitting
# 	dataset I/EST_OUEST: 7 by 18
# 	dataset I/RESEAU_MAERA: 6 by 18
# 	dataset I/RESEAU: 6 by 18
# 	dataset IV: 6 by 21
# Pump Stattion
# 	dataset I/EST_OUEST: 4 by 58
# 	dataset I/RESEAU_MAERA: 25 by 58
# 	dataset I/RESEAU: 8 by 58
# 	dataset IV: 5 by 66
# Sewage Treatment
# 	dataset I/EST_OUEST: 8 by 17
# 	dataset I/RESEAU_MAERA: 10 by 17
# 	dataset I/RESEAU: 10 by 17
# 	dataset IV: 8 by 31
# Structure
# 	dataset I/EST_OUEST: 4 by 16
# 	dataset I/RESEAU_MAERA: 4 by 16
# 	dataset I/RESEAU: 4 by 16
# 	dataset II: 0 by 8
# 	dataset III/M3M: 0 by 5
# 	dataset IV: 6 by 25
# Accessories
# 	dataset II: 0 by 9
# 	dataset III/M3M: 0 by 4
# Others
# 	dataset IV: 0 by 6
# 	dataset IV: 0 by 16

# %% [markdown]
# ### Write data to Latex file

# %%
similar_attributes = {} # {(attr, type): file}

# %%
# write_data_2_latex_items
def write_data_2_latex_items(file_out, file_name, attributes):
    if attributes is None:
        return
    
    subsection = file_name.split('/')[-1] + ' from ' + '\\textit{' + file_name.removesuffix(file_name.split('/')[-1])[:-1] + '}'
    
    file_out.write(('\\subsection{' + subsection + '}\n').replace('_', '\_'))
    file_out.write('\\begin{description}\n')
    
    attr_nullVals = []
    
    for attr in attributes:
        # Attribute Name
        line = '\\item[' + '\\textbf{' + attr +  ':}] ' 
        
        # Type
        line += '\\textit{Type}: ' + str(attributes[attr]['type'])
        
        # Min, Max
        if attributes[attr]['min'] is not None and attributes[attr]['max'] is not None:
            line += ', \\textit{Min-Max}: [' + str(attributes[attr]['min']) + ',' + str(attributes[attr]['max']) + ']'
        
        # Nbr null values
        line += ', \\textit{Not null values}: ' + str(attributes[attr]['not_null_values'])
        
        # Values:{ vals}
        if attributes[attr]['values'] is not None:
            line += ', \\textit{Values}: \{'
            line += str(attributes[attr]['values'][0])
            for val in attributes[attr]['values'][1:]:
                line += ', ' + str(val)
            line += '\}'
            
        
        # Write the line to file
        file_out.write(line.replace('_', '\_') + '\n')
        attr_nullVals.append([attr, attributes[attr]['not_null_values']])
        

    file_out.write('\\end{description}\n')
    
    # create a table with the null values  | Attribute | Null values | Attribute | Null values |
    file_out.write('The following table shows the number of null values for each attribute: \n')
    file_out.write('\\begin{table}[H]\n')
    file_out.write('\\centering\n')
    file_out.write('\\begin{tabular}{|c|c|c|c|}\n')
    file_out.write('\\hline\n')
    file_out.write('\\rowcolor{gray!25}')
    file_out.write('\\textbf{Attribute} & \\textbf{Filled values} & \\textbf{Attribute} & \\textbf{Filled values} \\\\ \\hline\n')
    
    green = "\\cellcolor{green!50}"
    red = "\\cellcolor{red!50}"
    
    for i in range(0, len(attr_nullVals), 2):
        attr1 = attr_nullVals[i][0]
        vals1_str = attr_nullVals[i][1].split('/')
        vals1 = [int(vals1_str[0]), int(vals1_str[1])]
        perc1 = "N/A"
        cell1_color = ""

        if vals1[1] != 0:
            if vals1[0]/vals1[1] > 0.9:
                cell1_color = green
            elif vals1[0]/vals1[1] < 0.3:
                cell1_color = red
                
            if vals1[0]/vals1[1] > 0.9999 and vals1[0]/vals1[1] < 1:
                perc1 = "~100\%"
            else:
                perc1 = "{:.2f}".format(vals1[0]/vals1[1]*100) + "\%"
        
        
        if i+1 == len(attr_nullVals):
            file_out.write(cell1_color + attr1.replace('_', '\_') + ' & ' + perc1 + ' & & \\\\ \\hline\n')
            break
        
        attr2 = attr_nullVals[i+1][0]
        vals2_str = attr_nullVals[i+1][1].split('/')
        vals2 = [int(vals2_str[0]), int(vals2_str[1])]
        perc2 = "N/A"
        cell2_color = ""
        
        if vals2[1] != 0:
            if vals2[0]/vals2[1] > 0.9:
                cell2_color = green
            elif vals2[0]/vals2[1] < 0.3:
                cell2_color = red
                
            if vals2[0]/vals2[1] > 0.9999 and vals2[0]/vals2[1] < 1:
                perc2 = "~100\%"
            else:
                perc2 = "{:.2f}".format(vals2[0]/vals2[1]*100) + "\%"
        
        file_out.write(cell1_color + attr1.replace('_', '\_') + ' & ' + perc1 + ' & ' + cell2_color + attr2.replace('_', '\_') + ' & ' + perc2 + ' \\\\ \\hline\n')
        
    file_out.write('\\end{tabular}\n')
    file_out.write('\\caption{Null values for each attribute}\n')
    file_out.write('\\label{tab:null_values}\n')
    file_out.write('\\end{table}\n')

# %%
# Write the data to latex file
with open(out_tex_file, 'w') as file_out:
    for comp,files in comp_file_dict.items():
        if len(files) > 0:
            file_out.write(('\\section{' + comp + '}\n').replace('_', '\_'))
        for file in files:
                if (file + '.shp') in fld_types_by_file:
                    write_data_2_latex_items(file_out, file, fld_types_by_file[file + '.shp'])
                else:
                    print('File {} not found'.format(file))
